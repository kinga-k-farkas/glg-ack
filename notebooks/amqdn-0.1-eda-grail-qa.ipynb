# %% [markdown]
# ## EDA - Grail QA
#
# The data is in `JSON` format, and the schema is provided below. For our purposes, we only care about "domains" and "question".
# ```
# {
#   "answer": {
#     "[]": {
#       "answer_argument": "string",
#       "answer_type": "string",
#       "entity_name": "string"
#     }
#   },
#   "domains": {
#     "[]": "string"
#   },
#   "function": "string",
#   "graph_query": {
#     "edges": {
#       "[]": {
#         "end": "int32",
#         "friendly_name": "string",
#         "relation": "string",
#         "start": "int32"
#       }
#     },
#     "nodes": {
#       "[]": {
#         "class": "string",
#         "friendly_name": "string",
#         "function": "string",
#         "id": "string",
#         "nid": "int32",
#         "node_type": "string",
#         "question_node": "int32"
#       }
#     }
#   },
#   "level": "string",
#   "num_edge": "int32",
#   "num_node": "int32",
#   "qid": "string",
#   "question": "string",
#   "s_expression": "string",
#   "sparql_query": "string"
# }
# ```

# %%
import pandas as pd

pd.options.display.max_rows = 150
pd.options.display.max_colwidth = 0

# %%
from src.data.utils import *

train = pd.DataFrame(get_domains_and_questions('train', 'grail_qa'))

# %%
train.head()
# Out:
#                        domains  \
# 0  medicine
# 1  education
# 2  religion
# 3  user.patrick.default_domain
# 4  language
#
#                                                                                            questions
# 0  oxybutynin chloride 5 extended release film coated tablet is the ingredients of what routed drug?
# 1  the type single-sex school are in which institutions?
# 2  the leaders of the earliest established religious organization are given what title?
# 3  on 07/01/1970, which warship v1.1 was hit?
# 4  what is the language regulator of basque?

# %%
train.domains.value_counts()
# Out:
# music                                          2280
# fictional_universe                             2120
# book                                           2060
# medicine                                       2002
# computer                                       1923
# astronomy                                      1534
# people                                         1468
# sports                                         1383
# spaceflight                                    1381
# tv                                             1321
# biology                                        1248
# government                                     1247
# food                                           1200
# comic_books                                    1054
# education                                      994
# aviation                                       930
# business                                       871
# time                                           823
# architecture                                   795
# religion                                       787
# automotive                                     759
# meteorology                                    739
# amusement_parks                                726
# broadcast                                      701
# digicams                                       686
# law                                            655
# geography                                      645
# media_common                                   629
# visual_art                                     548
# theater                                        521
# olympics                                       501
# internet                                       495
# boats                                          464
# cricket                                        453
# organization                                   443
# travel                                         428
# royalty                                        413
# engineering                                    409
# wine                                           385
# opera                                          376
# language                                       351
# soccer                                         334
# distilled_spirits                              334
# exhibitions                                    305
# military                                       257
# tennis                                         213
# interests                                      201
# skiing                                         183
# protected_sites                                177
# ice_hockey                                     168
# martial_arts                                   154
# freebase                                       149
# dining                                         138
# basketball                                     138
# transportation                                 134
# base.lightweight                               125
# zoos                                           125
# projects                                       117
# physics                                        114
# symbols                                        107
# base.exoplanetology                            106
# common                                         91
# bicycles                                       87
# education;people                               84
# comic_strips                                   82
# time;religion                                  74
# celebrities                                    73
# geology                                        68
# fashion                                        68
# chess                                          54
# boxing                                         51
# religion;people                                50
# fictional_universe;comic_books                 48
# food;wine                                      42
# library                                        42
# book;education                                 39
# royalty;people                                 39
# business;organization                          38
# soccer;time                                    36
# dining;food                                    35
# fictional_universe;media_common                35
# book;media_common                              31
# book;periodicals                               31
# business;digicams                              30
# book;people                                    29
# influence                                      29
# dining;travel                                  29
# media_common;tv                                28
# music;tv                                       25
# business;people                                24
# theater;media_common                           22
# opera;music                                    22
# book;fictional_universe                        22
# astronomy;base.exoplanetology                  21
# media_common;comic_books                       20
# user.patrick.default_domain                    19
# martial_arts;education;people                  18
# media_common;people                            17
# periodicals                                    16
# dining;people                                  16
# government;organization                        15
# transportation;travel                          15
# travel;organization                            15
# sports;broadcast;people                        15
# biology;people                                 15
# architecture;travel                            15
# basketball;media_common                        15
# business;medicine                              15
# food;dining                                    14
# theater;architecture                           14
# fictional_universe;sports                      14
# automotive;organization                        14
# time;military                                  14
# broadcast;tv                                   14
# language;tv                                    13
# book;music                                     13
# soccer;sports                                  13
# interests;people                               11
# common;tv                                      11
# user.jonathanwlowe.location                    9
# type                                           9
# broadcast;education                            9
# engineering;projects                           8
# sports;ice_hockey                              7
# book;language                                  7
# fictional_universe;people                      7
# fictional_universe;media_common;comic_books    7
# biology;geology                                6
# time;media_common;spaceflight                  6
# medicine;organization                          6
# people;law                                     6
# aviation;common                                6
# aviation;time                                  6
# boxing;sports                                  6
# astronomy;education                            5
# type;people                                    5
# medicine;people                                5
# book;travel                                    5
# comic_strips;media_common                      5
# soccer;media_common                            5
# comedy                                         5
# opera;people                                   5
# people;geography                               4
# time;olympics                                  4
# biology;zoos                                   4
# food;people                                    3
# Name: domains, dtype: int64

# %% [markdown]
# From this list, there are a handful of candidate subdomains that may fall under the umbrella domains of `healthcare` and `technology`.

# %% [markdown]
# ## Candidates for `healthcare`

# %%
from functools import partial

def get_candidate_sample(df, subdomain, n=5):
    return df.loc[df.domains == subdomain].sample(n)

get_sample = partial(get_candidate_sample, train)

# %%
get_sample('medicine')
# Out:
#         domains  \
# 3836   medicine
# 19795  medicine
# 27564  medicine
# 43138  medicine
# 1847   medicine
#
#                                                                                                                 questions
# 3836   what are some of the symptoms of neck pain?
# 19795  what medications should not be used during acute pain
# 27564  which drug formulation has the manufactured forms of tylenol cold cough and severe congestion 325/10/200/5 liquid?
# 43138  what medical treatments have the side effect symptoms of pains?
# 1847   driving is a contradiction for which medical treatment?

# %%
get_sample('biology')
# Out:
#        domains  \
# 28721  biology
# 13632  biology
# 28319  biology
# 40553  biology
# 37268  biology
#
#                                                                                                                        questions
# 28721  find an organism that weighs less than 21.3.
# 13632  what animal breed's origin is macedonia?
# 28319  which plant disease is hosted on oats?
# 40553  which organism classifications rank lower than infraorder ?
# 37268  what is the name of the cytogenic band that is associated with a genomic locus also associated with chromosome 4 (human)?

# %%
get_sample('biology;people')
# Out:
#               domains  \
# 8510   biology;people
# 28973  biology;people
# 38852  biology;people
# 16896  biology;people
# 7444   biology;people
#
#                                                            questions
# 8510   how many illustrators are in the same gender with codex?
# 28973  little wolf shares a gender with how many illustrators?
# 38852  how many illustrators are in the same gender with risen star?
# 16896  herman the bull is the same gender as how many illustrators?
# 7444   how many illustrators share a gender with lights up?

# %%
get_sample('business;medicine')
# Out:
#                  domains  \
# 39923  business;medicine
# 36111  business;medicine
# 8438   business;medicine
# 796    business;medicine
# 3299   business;medicine
#
#                                                                          questions
# 39923  what is the largest manufactured drug with the brand of micardis?
# 36111  what is the largest drug manufactured with the brand colace?
# 8438   what is the largest manufactured drug retrovir?
# 796    name the largest manufactured drug with the brand ofrequip?
# 3299   what is the largest manufactured drug with the brand of therabenzaprine-90?

# %% [markdown]
# ## Candidates for `technology`

# %%
get_sample('computer')
# Out:
#         domains  \
# 16573  computer
# 34720  computer
# 7275   computer
# 31557  computer
# 21135  computer
#
#                                                                                          questions
# 16573  zx printer is the peripherals within which computer emulator?
# 34720  what computer manufacturer/brand has a computer line that is the parent model of apple iic?
# 7275   which programming language is influenced by hypercard ?
# 31557  what family of computers is the zx interface 2 compatible with?
# 21135  which file format has the genre of package manager?

# %%
get_sample('spaceflight')
# Out:
#            domains  \
# 18687  spaceflight
# 35660  spaceflight
# 10163  spaceflight
# 22580  spaceflight
# 24140  spaceflight
#
#                                                                                                                              questions
# 18687  the name of the space mission that has astronaut mark c. lee?
# 35660  263.3 is the isp of which rocket engine?
# 10163  which rocket engine that is manufactured by npo energomash has an isp (vacuum) bigger than 400.0?
# 22580  the designer of rd-118 designed what other rocket engines?
# 24140  find a bipropellant rocket engine, that has a status of test fired, whose thrust (sea level) is more than or equal to 784000.0.

# %%
get_sample('aviation')
# Out:
#         domains  \
# 11585  aviation
# 18700  aviation
# 24330  aviation
# 34002  aviation
# 14081  aviation
#
#                                                                   questions
# 11585  which aviation incident is of the type improvised explosive devices?
# 18700  boeing b737 is part of which aircraft model line?
# 24330  find information about the wuhan airlines aviation incident.
# 34002  which airline's hub includes baghdad international airport?
# 14081  what models of aircraft were designed by john carver meadows frost?

# %%
get_sample('automotive')
# Out:
#           domains  \
# 4440   automotive
# 15416  automotive
# 22043  automotive
# 23721  automotive
# 7342   automotive
#
#                                                                                                      questions
# 4440   can you name the engines that use the same fuel as the hyundai 2.0l 4 cylinder 210 hp 223 ft-lbs turbo?
# 15416  which class is the automotive class of automobile model whose sister model is the crown victoria?
# 22043  which automobile has a generation number of 8?
# 23721  which automobile model directly preceded the second generation mercury topaz?
# 7342   what is the automobile generation that uses the platform of ford d3 platform?

# %%
get_sample('broadcast')
# Out:
#          domains  \
# 39856  broadcast
# 26442  broadcast
# 20592  broadcast
# 21792  broadcast
# 29314  broadcast
#
#                                                                                                                            questions
# 39856  what capital of administrative division is the location of a broadcast producer that is the producer of wcai/wnan talk radio?
# 26442  what is the radio format with format of wjse and stations of ktmp?
# 20592  what is the broadcast content with genre latino?
# 21792  2008-11-23 was the end date of which broadcast content?
# 29314  what is an example of a house music and urban contemporary broadcast content?

# %%
get_sample('internet')
# Out:
#         domains  \
# 8546   internet
# 24332  internet
# 6848   internet
# 8870   internet
# 2822   internet
#
#                                                                                          questions
# 8546   which website has the api of javascript object notation?
# 24332  the website ended most recently is a member of which website category?
# 6848   name the subsites of yssy atc simulation.
# 8870   what is the website that belongs to the same website category with mess with msn messenger?
# 2822   matias basilico owns how many active websites?

# %%
get_sample('engineering')
# Out:
#            domains  \
# 38974  engineering
# 22537  engineering
# 32908  engineering
# 34062  engineering
# 23336  engineering
#
#                                                                     questions
# 38974  what is the upper material class of aviation fuel?
# 22537  what are the names of reaction engines with a mass of at least 5393.0?
# 32908  ac motor is a subcategory of which category of engine?
# 34062  a ranted voltage of 250.0 is the voltage of what kind of power plug?
# 23336  what are the upper material classes of wood?

# %%
get_sample('military')
# Out:
#         domains  \
# 33676  military
# 16029  military
# 16583  military
# 6918   military
# 10920  military
#
#                                                                         questions
# 33676  1st red banner army belongs to which armed force sub-division?
# 16029  the 7th illinois volunteer infantry regiment belongs to which armed force?
# 16583  state of texas is from which armed force military combatant?
# 6918   gestapo is included in which armed force?
# 10920  which military person participated in battle of grozny?

# %% [markdown]
# ## Ontology
#
# In a real-time meeting, we took samples as below of candidate subdomains and agreed on which of them we thought should map to `healthcare` or `technology`.

# %%
get_candidate_sample(train, 'engineering', n=10)
# Out:
#            domains  \
# 25213  engineering
# 13139  engineering
# 30912  engineering
# 27971  engineering
# 15982  engineering
# 33095  engineering
# 42663  engineering
# 12203  engineering
# 8236   engineering
# 18684  engineering
#
#                                                                            questions
# 25213  2vsb is the child modulation of which signal modulation mode?
# 13139  the heinkel hes 40 engine is under what category?
# 30912  which piston engine has the capacity of 27.0?
# 27971  what material can be classified with grey iron?
# 15982  which engine category has sub-categories like turbofan?
# 33095  what sub-category does rolls-royce vulture fall under in the engine category?
# 42663  vantage xp-360 is the variation of what engine?
# 12203  malleable iron and what other materials are in the same class?
# 8236   what signal modulation mode is the child modulation of a-vsb?
# 18684  which battery shape format is the size of aaaa battery?
